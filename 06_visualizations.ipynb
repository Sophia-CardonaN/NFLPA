# %% [markdown]
# # 6. Visualizations for Final Report
# ## Coast-to-Coast Travel Analysis
#
# This notebook creates:
# - 8-10 publication-quality visualizations
# - Charts for executive summary
# - Supporting figures for detailed write-up
#
# **Output**: High-quality figures ready for competition submission

# %% [markdown]
# ---
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Set publication quality style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("paper", font_scale=1.5)
sns.set_palette("Set2")

# Custom color scheme
WEST_COAST_COLOR = '#1f77b4'  # Blue
EAST_COAST_COLOR = '#ff7f0e'  # Orange
NEUTRAL_COLOR = '#2ca02c'     # Green

# Load all processed data
schedules = pd.read_csv('data_schedules_with_travel.csv')
# season_analysis = pd.read_csv('data_season_analysis.csv')  # If available

print("✓ Setup complete")

# %% [markdown]
# ---
# ## Figure 1: Travel Burden Distribution by Team
#
# **Purpose**: Show which teams face most coast-to-coast travel
#
# **For**: Executive summary

# %%
# TODO: Create horizontal bar chart
# X-axis: Number of coast-to-coast games (2021-2024)
# Y-axis: Team abbreviations
# Color: West Coast teams (blue), East Coast teams (orange), Others (green)

# fig, ax = plt.subplots(figsize=(12, 10))
# Calculate travel burden per team
# Sort by total c2c games
# Color code bars
# Add value labels on bars
# plt.title('Coast-to-Coast Travel Burden by Team (2021-2024)', fontweight='bold', fontsize=16)
# plt.xlabel('Coast-to-Coast Games', fontsize=14)
# plt.tight_layout()
# plt.savefig('fig1_travel_burden.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 2: Win Rate by Travel Category
#
# **Purpose**: Show immediate impact of travel on performance
#
# **For**: Executive summary

# %%
# TODO: Create grouped bar chart
# Categories: Home | Same TZ | 1 Zone | 2 Zones | 3 Zones (C2C)
# Y-axis: Win percentage
# Include sample size (n) above each bar
# Add error bars (95% confidence intervals)

# fig, ax = plt.subplots(figsize=(12, 7))
# Calculate win % for each category
# plt.bar(...)
# plt.axhline(y=0.5, color='gray', linestyle='--', label='50% (Random Chance)')
# plt.title('Win Percentage by Travel Distance', fontweight='bold', fontsize=16)
# plt.ylabel('Win Percentage', fontsize=14)
# plt.xlabel('Travel Category', fontsize=14)
# plt.savefig('fig2_win_rate.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 3: Performance Metrics Comparison
#
# **Purpose**: Multi-metric view of travel impact
#
# **For**: Detailed write-up

# %%
# TODO: Create grouped bar chart with multiple metrics
# Metrics: Points, Total Yards, Turnovers, 3rd Down %
# Compare: Home games vs Coast-to-coast travel
# Show as % difference from home baseline

# fig, ax = plt.subplots(figsize=(12, 7))
# metrics = ['Points', 'Total Yards', 'Turnovers', '3rd Down %']
# x = np.arange(len(metrics))
# width = 0.35
# plt.bar(x - width/2, home_values, width, label='Home Games')
# plt.bar(x + width/2, c2c_values, width, label='Coast-to-Coast')
# plt.title('Performance Degradation with Coast-to-Coast Travel', fontweight='bold')
# plt.savefig('fig3_performance_metrics.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 4: Recovery Timeline
#
# **Purpose**: Show hangover effects and recovery pattern
#
# **For**: Executive summary

# %%
# TODO: Create line chart showing recovery
# X-axis: Games relative to coast-to-coast travel (-1, 0, +1, +2, +3)
# Y-axis: Win percentage or points scored
# Baseline (no travel) as dashed horizontal line

# fig, ax = plt.subplots(figsize=(12, 7))
# games = ['Before', 'During C2C', '1 Game After', '2 Games After', 'Baseline']
# plt.plot(games, performance, marker='o', linewidth=2.5, markersize=10)
# plt.axhline(y=baseline, color='gray', linestyle='--', label='No Travel Baseline')
# plt.title('Performance Recovery Timeline After Coast-to-Coast Travel', fontweight='bold')
# plt.ylabel('Performance Metric', fontsize=14)
# plt.xlabel('Game Position Relative to Travel', fontsize=14)
# plt.savefig('fig4_recovery_timeline.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 5: Season Win Rate vs Travel Burden
#
# **Purpose**: Show cumulative season-level impact
#
# **For**: Executive summary

# %%
# TODO: Create scatter plot with regression line
# X-axis: Coast-to-coast games in season
# Y-axis: Final win percentage
# Color: West Coast (blue), East Coast (orange), Other (green)
# Add trend line and R² value

# fig, ax = plt.subplots(figsize=(12, 8))
# sns.scatterplot(data=season_data, x='c2c_games', y='win_pct', 
#                 hue='coast', s=150, alpha=0.7)
# Add regression line
# from scipy.stats import linregress
# slope, intercept, r_value, p_value, std_err = linregress(x, y)
# plt.plot(x, slope*x + intercept, 'r--', linewidth=2)
# plt.text(x_pos, y_pos, f'R² = {r_value**2:.3f}\np = {p_value:.4f}')
# plt.title('Travel Burden Predicts Season Outcomes', fontweight='bold')
# plt.xlabel('Coast-to-Coast Games (Season)', fontsize=14)
# plt.ylabel('Win Percentage', fontsize=14)
# plt.savefig('fig5_season_correlation.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 6: West vs East Coast Disparity
#
# **Purpose**: Highlight competitive inequity
#
# **For**: Executive summary

# %%
# TODO: Create side-by-side comparison
# Two panels:
# Panel 1: Average C2C games per season (bar chart)
# Panel 2: Average win % (bar chart)
# Show West Coast vs East Coast
# Include statistical significance markers

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Panel 1: Travel burden
# coasts = ['West Coast', 'East Coast']
# ax1.bar(coasts, [west_travel, east_travel], color=[WEST_COAST_COLOR, EAST_COAST_COLOR])
# ax1.set_title('Travel Burden Disparity')
# ax1.set_ylabel('Avg C2C Games per Season')

# Panel 2: Performance
# ax2.bar(coasts, [west_win_pct, east_win_pct], color=[WEST_COAST_COLOR, EAST_COAST_COLOR])
# ax2.set_title('Season Performance')
# ax2.set_ylabel('Average Win Percentage')

# plt.suptitle('Competitive Inequity: West Coast vs East Coast', fontweight='bold', fontsize=16)
# plt.tight_layout()
# plt.savefig('fig6_coast_disparity.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 7: Travel Direction Impact
#
# **Purpose**: Show East→West vs West→East differences
#
# **For**: Detailed write-up

# %%
# TODO: Create grouped bar chart
# Compare performance for:
# - East Coast teams traveling West
# - West Coast teams traveling East
# Metrics: Win %, Points, Yards

# fig, ax = plt.subplots(figsize=(10, 7))
# directions = ['East→West', 'West→East']
# metrics = ['Win %', 'Points', 'Total Yards']
# Create grouped bars
# plt.title('Travel Direction Matters: Body Clock Impact', fontweight='bold')
# plt.savefig('fig7_direction_impact.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 8: Playoff Impact
#
# **Purpose**: Show how travel affects playoff chances
#
# **For**: Detailed write-up

# %%
# TODO: Create box plot comparison
# Two groups: Made Playoffs vs Missed Playoffs
# Y-axis: Coast-to-coast games that season
# Show median, quartiles, outliers
# Add statistical test result (p-value)

# fig, ax = plt.subplots(figsize=(10, 7))
# sns.boxplot(data=season_data, x='made_playoffs', y='c2c_games',
#             palette=['lightcoral', 'lightgreen'])
# plt.title('Travel Burden and Playoff Qualification', fontweight='bold')
# plt.xlabel('Playoff Status', fontsize=14)
# plt.ylabel('Coast-to-Coast Games', fontsize=14)
# plt.savefig('fig8_playoff_impact.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 9: Cumulative Fatigue Pattern
#
# **Purpose**: Show season-long accumulation of travel effects
#
# **For**: Detailed write-up

# %%
# TODO: Create line chart across season
# X-axis: Season stage (Early, Mid, Late)
# Y-axis: Performance decline from baseline
# Separate lines for different travel frequencies
# Show fatigue accumulation

# fig, ax = plt.subplots(figsize=(12, 7))
# stages = ['Early\n(Weeks 1-6)', 'Mid\n(Weeks 7-12)', 'Late\n(Weeks 13-18)']
# plt.plot(stages, high_travel_teams, marker='o', label='High Travel Teams', linewidth=2.5)
# plt.plot(stages, low_travel_teams, marker='s', label='Low Travel Teams', linewidth=2.5)
# plt.title('Cumulative Fatigue Across Season', fontweight='bold')
# plt.ylabel('Performance Decline (%)', fontsize=14)
# plt.xlabel('Season Stage', fontsize=14)
# plt.savefig('fig9_cumulative_fatigue.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Figure 10: Body Clock Impact
#
# **Purpose**: Show how game time relative to body clock affects performance
#
# **For**: Detailed write-up (optional)

# %%
# TODO: Create heatmap or line chart
# X-axis: Game kickoff time (in traveler's body clock)
# Y-axis: Performance metric
# Highlight "worst" times (e.g., 10am body clock for West Coast teams)

# fig, ax = plt.subplots(figsize=(12, 7))
# times = ['10am', '1pm', '4pm', '8pm']  # Body clock times
# plt.plot(times, performance, marker='o', linewidth=2.5, markersize=10)
# plt.axvspan('10am', '1pm', alpha=0.2, color='red', label='High Circadian Disruption')
# plt.title('Body Clock Impact on Performance', fontweight='bold')
# plt.xlabel('Kickoff Time (Body Clock)', fontsize=14)
# plt.ylabel('Win Percentage', fontsize=14)
# plt.savefig('fig10_body_clock.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ---
# ## Export All Figures

# %%
# TODO: Verify all figures saved
import os

figures = [
    'fig1_travel_burden.png',
    'fig2_win_rate.png',
    'fig3_performance_metrics.png',
    'fig4_recovery_timeline.png',
    'fig5_season_correlation.png',
    'fig6_coast_disparity.png',
    'fig7_direction_impact.png',
    'fig8_playoff_impact.png',
    'fig9_cumulative_fatigue.png',
    'fig10_body_clock.png'
]

print("Figure Status:")
for fig in figures:
    status = "✓" if os.path.exists(fig) else "✗"
    print(f"  {status} {fig}")

print("\n✓ All visualizations ready for report")

# %% [markdown]
# ---
# ## Summary
#
# **Figures Created:**
# 1. Travel burden by team (immediate impact)
# 2. Win rate by travel category (dose-response)
# 3. Multi-metric performance comparison
# 4. Recovery timeline (hangover effects)
# 5. Season correlation (cumulative impact)
# 6. Coast disparity (competitive inequity)
# 7. Travel direction impact
# 8. Playoff qualification impact
# 9. Cumulative seasonal fatigue
# 10. Body clock timing effects
#
# **Next Steps:**
# - Select 8-10 strongest figures for final report
# - Write executive summary with key visualizations
# - Complete detailed write-up with supporting figures
